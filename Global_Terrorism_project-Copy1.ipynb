# %% [markdown]
# # LetsGrowMore Data Science Virtual Internship Program July 2023

# %% [markdown]
# # BY: Gracy Jain

# %% [markdown]
# # INTERMEDIATE LEVEL TASK

# %% [markdown]
# # TASK 1: Global-Terrorism

# %% [markdown]
# # 1. Import necessary Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # 2- Reading The DataSet

# %%
df = pd.read_csv("C:/Users/Documents/Global Terrorism - START data/globalterrorismdb_0718dist.csv", encoding='ISO-8859-1')

# %% [markdown]
# # 3-Viewing The Dataset

# %%
df.head(6)
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
# 5  197001010002   1970       1     1        NaN         0        NaN      217
#
#           country_txt  region  ...  \
# 0  Dominican Republic       2  ...
# 1              Mexico       1  ...
# 2         Philippines       5  ...
# 3              Greece       8  ...
# 4               Japan       4  ...
# 5       United States       1  ...
#
#                                             addnotes  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5  The Cairo Chief of Police, William Petersen, r...
#
#                                               scite1  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5  "Police Chief Quits," Washington Post, January...
#
#                                               scite2  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5  "Cairo Police Chief Quits; Decries Local 'Mili...
#
#                                               scite3        dbsource  INT_LOG  \
# 0                                                NaN            PGIS        0
# 1                                                NaN            PGIS        0
# 2                                                NaN            PGIS       -9
# 3                                                NaN            PGIS       -9
# 4                                                NaN            PGIS       -9
# 5  Christopher Hewitt, "Political Violence and Te...  Hewitt Project       -9
#
#    INT_IDEO INT_MISC INT_ANY  related
# 0         0        0       0      NaN
# 1         1        1       1      NaN
# 2        -9        1       1      NaN
# 3        -9        1       1      NaN
# 4        -9        1       1      NaN
# 5        -9        0      -9      NaN
#
# [6 rows x 135 columns]

# %%
df.shape
# Out:
# (181691, 135)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Columns: 135 entries, eventid to related
# dtypes: float64(55), int64(22), object(58)
# memory usage: 187.1+ MB

# %%
df.columns.to_list
# Out:
# <bound method IndexOpsMixin.tolist of Index(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region',
#        ...
#        'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG',
#        'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object', length=135)>

# %%
df.describe()
# Out:
#             eventid          iyear         imonth           iday  \
# count  1.816910e+05  181691.000000  181691.000000  181691.000000
# mean   2.002705e+11    2002.638997       6.467277      15.505644
# std    1.325957e+09      13.259430       3.388303       8.814045
# min    1.970000e+11    1970.000000       0.000000       0.000000
# 25%    1.991021e+11    1991.000000       4.000000       8.000000
# 50%    2.009022e+11    2009.000000       6.000000      15.000000
# 75%    2.014081e+11    2014.000000       9.000000      23.000000
# max    2.017123e+11    2017.000000      12.000000      31.000000
#
#             extended        country         region       latitude  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean        0.045346     131.968501       7.160938      23.498343
# std         0.208063     112.414535       2.933408      18.569242
# min         0.000000       4.000000       1.000000     -53.154613
# 25%         0.000000      78.000000       5.000000      11.510046
# 50%         0.000000      98.000000       6.000000      31.467463
# 75%         0.000000     160.000000      10.000000      34.685087
# max         1.000000    1004.000000      12.000000      74.633553
#
#           longitude    specificity  ...     ransomamt   ransomamtus  \
# count  1.771340e+05  181685.000000  ...  1.350000e+03  5.630000e+02
# mean  -4.586957e+02       1.451452  ...  3.172530e+06  5.784865e+05
# std    2.047790e+05       0.995430  ...  3.021157e+07  7.077924e+06
# min   -8.618590e+07       1.000000  ... -9.900000e+01 -9.900000e+01
# 25%    4.545640e+00       1.000000  ...  0.000000e+00  0.000000e+00
# 50%    4.324651e+01       1.000000  ...  1.500000e+04  0.000000e+00
# 75%    6.871033e+01       1.000000  ...  4.000000e+05  0.000000e+00
# max    1.793667e+02       5.000000  ...  1.000000e+09  1.320000e+08
#
#          ransompaid  ransompaidus  hostkidoutcome     nreleased  \
# count  7.740000e+02    552.000000    10991.000000  10400.000000
# mean   7.179437e+05    240.378623        4.629242    -29.018269
# std    1.014392e+07   2940.967293        2.035360     65.720119
# min   -9.900000e+01    -99.000000        1.000000    -99.000000
# 25%   -9.900000e+01      0.000000        2.000000    -99.000000
# 50%    0.000000e+00      0.000000        4.000000      0.000000
# 75%    1.273412e+03      0.000000        7.000000      1.000000
# max    2.750000e+08  48000.000000        7.000000   2769.000000
#
#              INT_LOG       INT_IDEO       INT_MISC        INT_ANY
# count  181691.000000  181691.000000  181691.000000  181691.000000
# mean       -4.543731      -4.464398       0.090010      -3.945952
# std         4.543547       4.637152       0.568457       4.691325
# min        -9.000000      -9.000000      -9.000000      -9.000000
# 25%        -9.000000      -9.000000       0.000000      -9.000000
# 50%        -9.000000      -9.000000       0.000000       0.000000
# 75%         0.000000       0.000000       0.000000       0.000000
# max         1.000000       1.000000       1.000000       1.000000
#
# [8 rows x 77 columns]

# %% [markdown]
# # 4.Checking Null values

# %%
df.isnull().sum()
# Out:
# eventid            0
# iyear              0
# imonth             0
# iday               0
# approxdate    172452
#                ...
# INT_LOG            0
# INT_IDEO           0
# INT_MISC           0
# INT_ANY            0
# related       156653
# Length: 135, dtype: int64

# %%
null_percentage = df.isnull().sum().sum() / (df.shape[0] * df.shape[1]) * 100
rounded_percentage = round(null_percentage, 2)

print("Percentage of Null Values:", rounded_percentage, "%")
# Out:
# Percentage of Null Values: 56.48 %

# %%
#Count number of duplicates
print("Number of Duplicates Values:", df.duplicated().sum())
# Out:
# Number of Duplicates Values: 0

# %% [markdown]
# # 5.Rename Columns

# %%
df.rename(columns={'iyear':'Year','imonth':'Month','iday':"day",'gname':'Group','country_txt':'Country','region_txt':'Region','provstate':'State','city':'City','latitude':'latitude',
    'longitude':'longitude','summary':'summary','attacktype1_txt':'Attacktype','targtype1_txt':'Targettype','weaptype1_txt':'Weapon','nkill':'kill',
     'nwound':'Wound'},inplace=True)

# %%
df = df[['Year','Month','day','Country','State','Region','City','latitude','longitude',"Attacktype",'kill',
               'Wound','target1','summary','Group','Targettype','Weapon','motive']]

# %% [markdown]
# # 6.Handling Null values

# %%
df['kill']=df['kill'].fillna(0)
df['Wound']=df['Wound'].fillna(0)
df['Total_Casualty']=df['kill']+df['Wound']
df.head()
# Out:
#    Year  Month  day             Country    State                       Region  \
# 0  1970      7    2  Dominican Republic      NaN  Central America & Caribbean
# 1  1970      0    0              Mexico  Federal                North America
# 2  1970      1    0         Philippines   Tarlac               Southeast Asia
# 3  1970      1    0              Greece   Attica               Western Europe
# 4  1970      1    0               Japan  Fukouka                    East Asia
#
#             City   latitude   longitude                      Attacktype  kill  \
# 0  Santo Domingo  18.456792  -69.951164                   Assassination   1.0
# 1    Mexico city  19.371887  -99.086624     Hostage Taking (Kidnapping)   0.0
# 2        Unknown  15.478598  120.599741                   Assassination   1.0
# 3         Athens  37.997490   23.762728               Bombing/Explosion   0.0
# 4        Fukouka  33.580412  130.396361  Facility/Infrastructure Attack   0.0
#
#    Wound                  target1 summary                               Group  \
# 0    0.0             Julio Guzman     NaN                              MANO-D
# 1    0.0  Nadine Chaval, daughter     NaN  23rd of September Communist League
# 2    0.0                 Employee     NaN                             Unknown
# 3    0.0             U.S. Embassy     NaN                             Unknown
# 4    0.0           U.S. Consulate     NaN                             Unknown
#
#                     Targettype      Weapon motive  Total_Casualty
# 0  Private Citizens & Property     Unknown    NaN             1.0
# 1      Government (Diplomatic)     Unknown    NaN             0.0
# 2          Journalists & Media     Unknown    NaN             1.0
# 3      Government (Diplomatic)  Explosives    NaN             0.0
# 4      Government (Diplomatic)  Incendiary    NaN             0.0

# %%
attacks=df['Year'].value_counts()
attacks
# Out:
# 2014    16903
# 2015    14965
# 2016    13587
# 2013    12036
# 2017    10900
# 2012     8522
# 2011     5076
# 1992     5071
# 2010     4826
# 2008     4805
# 2009     4721
# 1991     4683
# 1989     4324
# 1990     3887
# 1988     3721
# 1984     3495
# 1994     3456
# 2007     3242
# 1997     3197
# 1987     3183
# 1995     3081
# 1996     3058
# 1985     2915
# 1983     2870
# 1986     2860
# 2006     2758
# 1979     2662
# 1980     2662
# 1981     2586
# 1982     2544
# 2005     2017
# 2001     1906
# 2000     1814
# 1978     1526
# 1999     1395
# 2002     1333
# 1977     1319
# 2003     1278
# 2004     1166
# 1998      934
# 1976      923
# 1975      740
# 1970      651
# 1974      581
# 1972      568
# 1973      473
# 1971      471
# Name: Year, dtype: int64

# %% [markdown]
# # 7.Performing Some Data Visualizations:

# %%
import matplotlib.pyplot as plt

years = df['Year'].unique()
years_count = df['Year'].value_counts(dropna=False).sort_index()

plt.figure(figsize=(18, 10))
plt.plot(years_count.index, years_count.values, marker='o', color='blue')
plt.xticks(rotation=60)
plt.xlabel('Attacking Year', fontsize=20)
plt.ylabel('Number of Attacks Each Year', fontsize=20)
plt.title('Attacks In Years', fontsize=17)
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

year = df['Year'].unique()
years_count = df['Year'].value_counts(dropna=False).sort_index()

plt.figure(figsize=(15, 7))
sns.barplot(x=year, y=years_count, palette="tab10")
plt.xticks(rotation=60, fontsize=10)
plt.yticks(fontsize=10)
plt.xlabel('Attacking Year', fontsize=10)
plt.ylabel('Number of Attacks Each Year', fontsize=14)
plt.title('Attacks In Years', fontsize=18)
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

cross_table = pd.crosstab(df['Year'], df['Region'])
colors = ['blue', 'green', 'orange', 'red', 'purple']  # Specify colors for each region

ax = cross_table.plot.area(stacked=False, figsize=(20, 10), color=colors)

ax.set_title('Terrorist Activities By Region In Each Year', fontsize=25)
ax.set_ylabel('Number of Attacks', fontsize=20)
ax.set_xlabel('Year', fontsize=20)

plt.show()

# %%
attacked_country = df.Country.value_counts()[:10]
attacked_country
# Out:
# Iraq              24636
# Pakistan          14368
# Afghanistan       12731
# India             11960
# Colombia           8306
# Philippines        6908
# Peru               6096
# El Salvador        5320
# United Kingdom     5235
# Turkey             4292
# Name: Country, dtype: int64

# %%
group_attack = df['Group'].value_counts()[1:10]
group_attack
# Out:
# Taliban                                             7478
# Islamic State of Iraq and the Levant (ISIL)         5613
# Shining Path (SL)                                   4555
# Farabundo Marti National Liberation Front (FMLN)    3351
# Al-Shabaab                                          3288
# New People's Army (NPA)                             2772
# Irish Republican Army (IRA)                         2671
# Revolutionary Armed Forces of Colombia (FARC)       2487
# Boko Haram                                          2418
# Name: Group, dtype: int64

# %%
attacked_country.plot.bar(color='cyan', figsize=(12, 6), width=0.5)

plt.xlabel('COUNTRY', fontsize=8)
plt.ylabel('NUMBER OF ATTACKS', fontsize=8)
plt.title('COUNTRY-WISE ATTACKS', fontsize=8)

plt.show()

# %%
group_attack.plot.bar(color='orange', figsize=(14, 6), width=0.4)

plt.xlabel('COUNTRY', fontsize=8)
plt.ylabel('NUMBER OF ATTACKS', fontsize=8)
plt.title('COUNTRY-WISE ATTACKS', fontsize=8)
plt.show()

# %%
df.head()
# Out:
#    Year  Month  day             Country    State                       Region  \
# 0  1970      7    2  Dominican Republic      NaN  Central America & Caribbean
# 1  1970      0    0              Mexico  Federal                North America
# 2  1970      1    0         Philippines   Tarlac               Southeast Asia
# 3  1970      1    0              Greece   Attica               Western Europe
# 4  1970      1    0               Japan  Fukouka                    East Asia
#
#             City   latitude   longitude                      Attacktype  kill  \
# 0  Santo Domingo  18.456792  -69.951164                   Assassination   1.0
# 1    Mexico city  19.371887  -99.086624     Hostage Taking (Kidnapping)   0.0
# 2        Unknown  15.478598  120.599741                   Assassination   1.0
# 3         Athens  37.997490   23.762728               Bombing/Explosion   0.0
# 4        Fukouka  33.580412  130.396361  Facility/Infrastructure Attack   0.0
#
#    Wound                  target1 summary                               Group  \
# 0    0.0             Julio Guzman     NaN                              MANO-D
# 1    0.0  Nadine Chaval, daughter     NaN  23rd of September Communist League
# 2    0.0                 Employee     NaN                             Unknown
# 3    0.0             U.S. Embassy     NaN                             Unknown
# 4    0.0           U.S. Consulate     NaN                             Unknown
#
#                     Targettype      Weapon motive  Total_Casualty
# 0  Private Citizens & Property     Unknown    NaN             1.0
# 1      Government (Diplomatic)     Unknown    NaN             0.0
# 2          Journalists & Media     Unknown    NaN             1.0
# 3      Government (Diplomatic)  Explosives    NaN             0.0
# 4      Government (Diplomatic)  Incendiary    NaN             0.0

# %%
import matplotlib.pyplot as plt

data = df[['Year', 'kill']].groupby(['Year']).sum().reset_index()

fig, ax4 = plt.subplots(figsize=(15, 6))
ax4.bar(data['Year'], data['kill'], alpha=0.7)

plt.xticks(rotation=50)
plt.title("People Died Due To Attack", fontsize=12)
plt.ylabel("Number of killed people", fontsize=12)
plt.xlabel('Year', fontsize=12)

ax4.spines["top"].set_visible(False)
ax4.spines["right"].set_visible(False)

plt.show()

# %%
attack_counts = df['Attacktype'].value_counts()

fig, ax = plt.subplots(figsize=(14, 5))
ax.bar(attack_counts.index, attack_counts, color='cyan',width=0.6)

plt.xticks(rotation=55)
plt.xlabel('Attack Type', fontsize=10)
plt.ylabel('Number of Attacks', fontsize=10)
plt.title('Number of Attacks by Attack Type', fontsize=15)

plt.show()

# %%
group_kill_sum = df[['Group', 'kill']].groupby('Group').sum().drop('Unknown').sort_values('kill', ascending=False).head(10)

fig, ax = plt.subplots(figsize=(17, 7))
ax.bar(group_kill_sum.index, group_kill_sum['kill'], color='yellow')

plt.title('Top 10 Terrorist Group Attacks', fontsize=15)
plt.xticks(rotation=55)
plt.xlabel('Terrorist Group Name', fontsize=15)
plt.ylabel('Number of Killed People', fontsize=15)

plt.show()

# %%
data=df[['Group','Country','kill',"Attacktype"]]
data=df.groupby(['Group','Country','Attacktype'],axis=0).sum().sort_values('kill',ascending=False).drop('Unknown').reset_index().head(10)
data
# Out:
#                                               Group      Country  \
# 0       Islamic State of Iraq and the Levant (ISIL)         Iraq
# 1                                           Taliban  Afghanistan
# 2                                           Taliban  Afghanistan
# 3                                        Boko Haram      Nigeria
# 4                                 Shining Path (SL)         Peru
# 5       Islamic State of Iraq and the Levant (ISIL)         Iraq
# 6  Farabundo Marti National Liberation Front (FMLN)  El Salvador
# 7                 Nicaraguan Democratic Force (FDN)    Nicaragua
# 8           Liberation Tigers of Tamil Eelam (LTTE)    Sri Lanka
# 9                                        Boko Haram      Nigeria
#
#                     Attacktype     Year  Month    day       latitude  \
# 0            Bombing/Explosion  6450978  20970  51873  109739.895729
# 1                Armed Assault  4234009  13745  33573   71292.203914
# 2            Bombing/Explosion  5730181  18890  43919   95422.933322
# 3                Armed Assault  1892916   5549  15133   10706.019263
# 4                Armed Assault  2281849   7344  17193  -12488.331567
# 5  Hostage Taking (Kidnapping)   933108   3215   6806   16075.944386
# 6                Armed Assault  3143450  10122  24222   19998.889982
# 7                Armed Assault  1428918   4708   9974    6982.322217
# 8                Armed Assault  1244868   4112   9562    5016.536871
# 9            Bombing/Explosion  1428101   4630  11271    8065.851008
#
#        longitude     kill    Wound  Total_Casualty
# 0  140020.074018  15533.0  21234.0         36767.0
# 1  140338.005770  11555.0   7346.0         18901.0
# 2  191030.427310  10126.0  14524.0         24650.0
# 3   11662.251722   9453.0   1323.0         10776.0
# 4  -78176.328448   8226.0   1114.0          9340.0
# 5   19792.285424   7452.0    140.0          7592.0
# 6 -129139.139341   6672.0   2910.0          9582.0
# 7  -45906.818147   6102.0    578.0          6680.0
# 8   48467.142334   5072.0   1486.0          6558.0
# 9    8378.514602   5055.0   5805.0         10860.0

# %% [markdown]
# # 8.Correlation and Heatmap:

# %%
df.corr()
# Out:
#                     Year     Month       day  latitude  longitude      kill  \
# Year            1.000000  0.000139  0.018254  0.166933   0.003917  0.021252
# Month           0.000139  1.000000  0.005497 -0.015978  -0.003880  0.004031
# day             0.018254  0.005497  1.000000  0.003423  -0.002285 -0.003225
# latitude        0.166933 -0.015978  0.003423  1.000000   0.001463 -0.013170
# longitude       0.003917 -0.003880 -0.002285  0.001463   1.000000 -0.000587
# kill            0.021252  0.004031 -0.003225 -0.013170  -0.000587  1.000000
# Wound           0.017484  0.003178 -0.001082  0.015920   0.000205  0.443326
# Total_Casualty  0.020675  0.003805 -0.001808  0.009899   0.000013  0.651885
#
#                    Wound  Total_Casualty
# Year            0.017484        0.020675
# Month           0.003178        0.003805
# day            -0.001082       -0.001808
# latitude        0.015920        0.009899
# longitude       0.000205        0.000013
# kill            0.443326        0.651885
# Wound           1.000000        0.968724
# Total_Casualty  0.968724        1.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming 'df' is already loaded with the DataFrame

plt.figure(figsize=(10, 5))
sns.heatmap(df.corr(), annot=True, cmap='viridis')
plt.show()

# %%
df['Year'].value_counts(dropna = False).sort_index()
# Out:
# 1970      651
# 1971      471
# 1972      568
# 1973      473
# 1974      581
# 1975      740
# 1976      923
# 1977     1319
# 1978     1526
# 1979     2662
# 1980     2662
# 1981     2586
# 1982     2544
# 1983     2870
# 1984     3495
# 1985     2915
# 1986     2860
# 1987     3183
# 1988     3721
# 1989     4324
# 1990     3887
# 1991     4683
# 1992     5071
# 1994     3456
# 1995     3081
# 1996     3058
# 1997     3197
# 1998      934
# 1999     1395
# 2000     1814
# 2001     1906
# 2002     1333
# 2003     1278
# 2004     1166
# 2005     2017
# 2006     2758
# 2007     3242
# 2008     4805
# 2009     4721
# 2010     4826
# 2011     5076
# 2012     8522
# 2013    12036
# 2014    16903
# 2015    14965
# 2016    13587
# 2017    10900
# Name: Year, dtype: int64

# %%
plt.subplots(figsize=(15,5))
sns.countplot('Region',data=df,palette='inferno',order=df['Region'].value_counts().index)
plt.xticks(rotation=90)
plt.xlabel('Regions')
plt.title('Number Of Attacks By Region')
plt.show()

# %%
Weapon_data = df['Weapon'].value_counts()
Weapon_data
# Out:
# Explosives                                                                     92426
# Firearms                                                                       58524
# Unknown                                                                        15157
# Incendiary                                                                     11135
# Melee                                                                           3655
# Chemical                                                                         321
# Sabotage Equipment                                                               141
# Vehicle (not to include vehicle-borne explosives, i.e., car or truck bombs)      136
# Other                                                                            114
# Biological                                                                        35
# Fake Weapons                                                                      33
# Radiological                                                                      14
# Name: Weapon, dtype: int64

# %%
plt.figure(figsize= (18,10))
sns.barplot(x = Weapon_data.index , y = Weapon_data.values)
plt.title('Most Used Weapon Type')
plt.xlabel('Weapon Type')
plt.ylabel('Attacks count')
plt.xticks(rotation = 90)
plt.show()

# %%
df['City'].value_counts().to_frame().sort_values('City',axis=0,ascending=False).head(10).plot(kind='bar',figsize=(20,10),color=['maroon'])
plt.xticks(rotation = 50)
plt.xlabel("City",fontsize=15)
plt.ylabel("Number of attack",fontsize=15)
plt.title("Top 10 most effected city",fontsize=20)
plt.show()

# %%
df['Attacktype'].value_counts().plot(kind='bar',figsize=(20,10),color='indigo')
plt.xticks(rotation = 50)
plt.xlabel("Attacktype",fontsize=15)
plt.ylabel("Number of attack",fontsize=15)
plt.title("Name of attacktype",fontsize=20)
plt.show()

# %%
df[['Attacktype','kill']].groupby(["Attacktype"],axis=0).sum().plot(kind='bar',figsize=(20,10),color=['red'])
plt.xticks(rotation=50)
plt.title("Number of killed ",fontsize=20)
plt.ylabel('Number of people',fontsize=15)
plt.xlabel('Attack type',fontsize=15)
plt.show()

# %%
df['Group'].value_counts().to_frame().drop('Unknown').head(10).plot(kind='bar',color='green',figsize=(20,10))
plt.title("Top 10 terrorist group attack",fontsize=20)
plt.xlabel("terrorist group name",fontsize=15)
plt.xticks(rotation=50)
plt.ylabel("Attack number",fontsize=15)
plt.show()

# %%
Target_data = df['Targettype'].value_counts().nlargest(n=15)
Target_data
# Out:
# Private Citizens & Property       43511
# Military                          27984
# Police                            24506
# Government (General)              21283
# Business                          20669
# Transportation                     6799
# Utilities                          6023
# Unknown                            5898
# Religious Figures/Institutions     4440
# Educational Institution            4322
# Government (Diplomatic)            3573
# Terrorists/Non-State Militia       3039
# Journalists & Media                2948
# Violent Political Party            1866
# Airports & Aircraft                1343
# Name: Targettype, dtype: int64

# %%
plt.figure(figsize= (18,10))
sns.barplot(x = Target_data.index , y = Target_data.values,palette='pastel')
plt.title('Most Frequent Target Type')
plt.xlabel('Target Type')
plt.xticks(rotation=50)
plt.ylabel('Attacks count')
plt.xticks(rotation = 90)
plt.show()

# %%
df=df[['Group','Country','kill']]
df=df.groupby(['Group','Country'],axis=0).sum().sort_values('kill',ascending=False).drop('Unknown').reset_index().head(10)
df
# Out:
#                                               Group      Country     kill
# 0       Islamic State of Iraq and the Levant (ISIL)         Iraq  31058.0
# 1                                           Taliban  Afghanistan  29269.0
# 2                                        Boko Haram      Nigeria  16917.0
# 3                                 Shining Path (SL)         Peru  11595.0
# 4           Liberation Tigers of Tamil Eelam (LTTE)    Sri Lanka  10928.0
# 5                                        Al-Shabaab      Somalia   8176.0
# 6  Farabundo Marti National Liberation Front (FMLN)  El Salvador   8019.0
# 7       Islamic State of Iraq and the Levant (ISIL)        Syria   6883.0
# 8                 Nicaraguan Democratic Force (FDN)    Nicaragua   6630.0
# 9                   Tehrik-i-Taliban Pakistan (TTP)     Pakistan   6014.0

# %%
kill = df.loc[:,'kill']
print('Number of people killed by terror attack:', int(sum(kill.dropna())))
# Out:
# Number of people killed by terror attack: 135489

# %%
CountryKill = df.pivot_table(columns='Country', values='kill', aggfunc='sum')
CountryKill
# Out:
# Country  Afghanistan  El Salvador     Iraq  Nicaragua  Nigeria  Pakistan  \
# kill         29269.0       8019.0  31058.0     6630.0  16917.0    6014.0
#
# Country     Peru  Somalia  Sri Lanka   Syria
# kill     11595.0   8176.0    10928.0  6883.0
